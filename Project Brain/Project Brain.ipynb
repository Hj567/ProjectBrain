# %%
import os
import sounddevice as sd
from scipy.io.wavfile import write
import time
import speech_recognition as sr
import glob


fs = 44100  # Sample rate
seconds = 3  # Duration of recording

myrecording = sd.rec(int(seconds * fs), fs, channels=2)
print("startSpeaking")
sd.wait()  # Wait until recording is finished
print("stop")

timestr = time.strftime("%Y%m%d-%H%M%S")
write(timestr+".wav", fs, myrecording)  # Save as WAV file)


path = 'data'
os.chdir("/Users/maheshjain/Desktop/test")
files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)

newest = files[-1]

time.sleep(1)

print(newest)
# Out:
# startSpeaking
# stop
# 20200801-225523.wav

# %%
import speech_recognition as sr
import pandas as pd
import os
import sounddevice as sd
from scipy.io.wavfile import write
import time
import glob
import operator
import yfinance as yf
from yahoo_fin import stock_info as si
import json
from PyDictionary import PyDictionary
import numpy as np
from newsapi import NewsApiClient
from urllib.request import urlopen

print("speakNow")
r=sr.Recognizer()

with sr.Microphone() as source:
    audio=r.listen(source)
   
    
try:
    
    a = r.recognize_google(audio)
    b = a.lower()
    b1= b.replace("'s","")

    print(b)

    test_str = b
    N = 1
    c = test_str.split(' ')[N-1] 
    
  
    word = b
    
    
    
except Exception:
    print("YoSHIT")
    

if c=="calculate":
    my_string=b.split(' ', 1)[1]
    def get_operator_fn(op):
        return {
            '+' : operator.add,
            '-' : operator.sub,
            'x' : operator.mul,
            'divided' :operator.__truediv__,
            'Mod' : operator.mod,
            'mod' : operator.mod,
            '^' : operator.xor,
        }[op]
    def eval_binary_expr(op1, oper, op2):
        op1,op2 = int(op1), int(op2)
        return get_operator_fn(oper)(op1, op2)
    print(eval_binary_expr(*(my_string.split())))
   
    
elif (word.find('record') != -1):
    if (b.find('for') != -1):
        fs = 44100  # Sample rate
        
        if (word.find('seconds') != -1):
            mystring = b1
            keyword = 'for ' 
            before_keyword, keyword, after_keyword = mystring.partition(keyword)
            query = after_keyword
            stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','stock','price','stockprice',"'s",'seconds']
            querywords = query.split()
            resultwords  = [word for word in querywords if word.lower() not in stopwords]
            result = ' '.join(resultwords)
            p = int(result)
            seconds = p  # Duration of recording
            myrecording = sd.rec(int(seconds * fs), fs, channels=2)
            print("startSpeaking")
            sd.wait()  # Wait until recording is finished
            print("stop")
            timestr = time.strftime("%Y%m%d-%H%M%S")
            write(timestr+".wav", fs, myrecording)  # Save as WAV file)
        
        elif (word.find('minutes') != -1):
            mystring = b1
            keyword = 'for ' 
            before_keyword, keyword, after_keyword = mystring.partition(keyword)
            query = after_keyword
            stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','stock','price','stockprice',"'s",'minutes','minute']
            querywords = query.split()
            resultwords  = [word for word in querywords if word.lower() not in stopwords]
            result = ' '.join(resultwords)
            p = (int(result))*60
            seconds = p  # Duration of recording
            myrecording = sd.rec(int(seconds * fs), fs, channels=2)
            print("startSpeaking")
            sd.wait()  # Wait until recording is finished
            print("stop")
            timestr = time.strftime("%Y%m%d-%H%M%S")
            write(timestr+".wav", fs, myrecording)  # Save as WAV file)
        
        elif (word.find('hours') != -1):
            mystring = b1
            keyword = 'for ' 
            before_keyword, keyword, after_keyword = mystring.partition(keyword)
            query = after_keyword
            stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','stock','price','stockprice',"'s",'hours','hour']
            querywords = query.split()
            resultwords  = [word for word in querywords if word.lower() not in stopwords]
            result = ' '.join(resultwords)
            p = int(result)*60*60
            seconds = p  # Duration of recording
            myrecording = sd.rec(int(seconds * fs), fs, channels=2)
            print("startSpeaking")
            sd.wait()  # Wait until recording is finished
            print("stop")
            timestr = time.strftime("%Y%m%d-%H%M%S")
            write(timestr+".wav", fs, myrecording)  # Save as WAV file)
            
            
        
        
    
    
        

elif (word.find('lecture') != -1):
        fs = 44100  # Sample rate
        seconds = 360  # Duration of recording
        myrecording = sd.rec(int(seconds * fs), fs, channels=2)
        print("startSpeaking")
        sd.wait()  # Wait until recording is finished
        print("stop")
        timestr = time.strftime("%Y%m%d-%H%M%S")
        write(timestr+".wav", fs, myrecording)  # Save as WAV file)  
        
elif(b.find('stock') != -1):
    if (b.find('of') != -1):
        mystring = b1
        keyword = 'of '
        before_keyword, keyword, after_keyword = mystring.partition(keyword)
        query = after_keyword
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','stock','price','stockprice',"'s"]
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        print(result)
        df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
        a = df[df.companyFinal==result]['Symbol'].to_numpy()
        

        def listToString(s):  
    
     
            str1 = ""  
    
    
            for ele in s:  
                str1 += ele   
    
    
            return str1  
        
        
        
        s = a 
        c= si.get_live_price(listToString(s))
        print(round(c,2))
        
    else:
        query = b1
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','stock','price','stockprice',"'s"]
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        result = result.split()[0]
        df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
        a = df[df.companyFinal==result]['Symbol'].to_numpy()
  

        def listToString(s):  
    
     
            str1 = ""  
    
    
            for ele in s:  
                str1 += ele   
    
    
            return str1  
        
        
        
        s = a 
        c= si.get_live_price(listToString(s))
        print(round(c,2))

elif(b.find('trading') != -1):
    
    mystring = b1
    keyword = 'is '
    before_keyword, keyword, after_keyword = mystring.partition(keyword)
    query = after_keyword
    stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','stock','price','stockprice',"'s",'trading','currently']
    querywords = query.split()
    resultwords  = [word for word in querywords if word.lower() not in stopwords]
    result = ' '.join(resultwords)
    print(result)
    df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
    a = df[df.companyFinal==result]['Symbol'].to_numpy()
        

    def listToString(s):  
    
     
        str1 = ""  
    
    
        for ele in s:  
            str1 += ele   
    
    
        return str1  
        
        
        
    s = a 
    c= si.get_live_price(listToString(s))
    print(round(c,2))
        


elif(b.find('meaning') != -1):
    if (b.find('of') != -1):
        mystring = b1
        keyword = 'of ' 
        before_keyword, keyword, after_keyword = mystring.partition(keyword)
        dictionary= PyDictionary(after_keyword)
        meaning1= dictionary.meaning(after_keyword)
        print(meaning1)

    else:
        query = b1
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning']
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        result = result.split()[0]
        dictionary= PyDictionary(result)
        meaning1= dictionary.meaning(result)
        print(meaning1)



        
elif(b.find('news') != -1):
    if (b.find('on') != -1):
        mystring = b1
        keyword = 'on ' 
        before_keyword, keyword, after_keyword = mystring.partition(keyword)
        newsapi = NewsApiClient(api_key='a6c42bd40c1c4c0daad38e69d4e8c035')
        data = newsapi.get_everything(q=after_keyword, language='en', sort_by='relevancy', page=1)
        articles = data['articles']
        for x, y in enumerate(articles):
            print(y["title"])

    else:
        query = b1
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning']
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        result = result.split()[0]
        newsapi = NewsApiClient(api_key='a6c42bd40c1c4c0daad38e69d4e8c035')
        data = newsapi.get_everything(q=result, language='en', sort_by='relevancy', page=1)
        articles = data['articles']
        for x, y in enumerate(articles):
            print(y["title"])

        
elif(b.find('positions') != -1):
    if (b.find('of') != -1):
        mystring = b1
        keyword = 'of ' 
        before_keyword, keyword, after_keyword = mystring.partition(keyword)
        df = pd.read_csv("CIK_Number.csv", encoding = "ISO-8859-1") 
        a = df[df.MANAGER_LOWER==after_keyword].iloc[0]['CIK_FINAL']
        b = str(a).zfill(10)
        u = 'https://financialmodelingprep.com/api/v3/form-thirteen/'
        r = b
        l = '?year=2020&apikey=b70734059c9a0b57684df376d90a0407'
        url = (u+r+l)
        print (url)

        response = urlopen(url)
        data = response.read().decode("utf-8")
        a= json.loads(data)
        df = pd.read_json (data)
        p = df.head(10)
        
        
        print((p[['nameOfIssuer', 'shares','titleOfClass']]))

        

    else:
        query = b1
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','holdings','of','positions']
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        result = result.split()[0]
        df = pd.read_csv("CIK_Number.csv", encoding = "ISO-8859-1") 
        a = df[df.MANAGER_LOWER==result].iloc[0]['CIK_FINAL']
        b = str(a).zfill(10)
        u = 'https://financialmodelingprep.com/api/v3/form-thirteen/'
        r = b
        l = '?year=2020&apikey=b70734059c9a0b57684df376d90a0407'
        url = (u+r+l)
        print (url)

        response = urlopen(url)
        data = response.read().decode("utf-8")
        a= json.loads(data)
        df = pd.read_json (data)
        p = df.head(10)
        
        
        print((p[['nameOfIssuer', 'shares','titleOfClass']]))

elif(b.find('holdings') != -1):
    if (b.find('of') != -1):
        mystring = b1
        keyword = 'of ' 
        before_keyword, keyword, after_keyword = mystring.partition(keyword)
        df = pd.read_csv("CIK_Number.csv", encoding = "ISO-8859-1") 
        a = df[df.MANAGER_LOWER==after_keyword].iloc[0]['CIK_FINAL']
        b = str(a).zfill(10)
        u = 'https://financialmodelingprep.com/api/v3/form-thirteen/'
        r = b
        l = '?year=2020&apikey=b70734059c9a0b57684df376d90a0407'
        url = (u+r+l)
        print (url)
        response = urlopen(url)
        data = response.read().decode("utf-8")
        a= json.loads(data)
        df = pd.read_json (data)
        a = df.head(10)
        
        
        print((p[['nameOfIssuer', 'shares','titleOfClass']]))

    else:
        query = b1
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','holdings','of','holding']
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        df = pd.read_csv("CIK_Number.csv", encoding = "ISO-8859-1") 
        a = df[df.MANAGER_LOWER==result].iloc[0]['CIK_FINAL']
        b = str(a).zfill(10)
        u = 'https://financialmodelingprep.com/api/v3/form-thirteen/'
        r = b
        l = '?year=2020&apikey=b70734059c9a0b57684df376d90a0407'
        url = (u+r+l)
        print (url)
        response = urlopen(url)
        data = response.read().decode("utf-8")
        a= json.loads(data)
        df = pd.read_json (data)
        a = df.head(10)
        
        
        print((p[['nameOfIssuer', 'shares','titleOfClass']]))

    
elif(b.find('position') != -1):

    query = b
    stopwords = ['news', 'who', 'is', 'at', 'he','meaning','holdings','of','holding','does','have', 'a','position','hold']
    querywords = query.split()
    resultwords  = [word for word in querywords if word.lower() not in stopwords]
    result = ' '.join(resultwords)
    mystring = result
    keyword = ' in ' 
    before_keyword, keyword, after_keyword = mystring.partition(keyword)
    df = pd.read_csv("CIK_Number.csv", encoding = "ISO-8859-1") 
    a = df[df.MANAGER_LOWER==before_keyword].iloc[0]['CIK_FINAL']
    b = str(a).zfill(10)
    u = 'https://financialmodelingprep.com/api/v3/form-thirteen/'
    r = b
    l = '?year=2020&apikey=b70734059c9a0b57684df376d90a0407'
    url = (u+r+l)
    print (url)
    response = urlopen(url)
    data = response.read().decode("utf-8")
    a= json.loads(data)
    df = pd.read_json (data)
    p = df.head()
    df1 = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
    a = df1[df1.companyFinal==after_keyword].iloc[0]['Symbol']
    mel_count=df['tickercusip'].str.contains(a).sum()
    if mel_count>0:
        print ("Yes according to 13F filings for 2020")
    else:
        print ("No according to 13F filings for 2020")
        
elif(b.find('finances') != -1):
    if (b.find('of') != -1):
        
        mystring = b1
        keyword = 'of ' 
        before_keyword, keyword, after_keyword = mystring.partition(keyword)
        df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
        a = df[df.companyFinal==after_keyword].iloc[0]['Symbol']
        def listToString(s):  
    
     
            str1 = ""  
    
    
            for ele in s:  
                str1 += ele   
    
    
            return str1  
        
        
        
        s = a 
        f= si.get_live_price(listToString(s))
        a1=str(round(f,2))
        
        tickerdata = yf.Ticker(a)
        tickerinfo = tickerdata.info
        one = tickerinfo['shortName']
        two = tickerinfo['marketCap']
        three = tickerinfo['bookValue']
        four = tickerinfo['sharesOutstanding']
        five = tickerinfo['dayLow']
        six = tickerinfo['dayHigh']
        seven = tickerinfo['profitMargins']
        eight = tickerinfo['twoHundredDayAverage']
        nine = tickerinfo['fiftyTwoWeekHigh']
        
        a= 'shortName : ' + str(one)
        a2 = 'Current Price : ' + a1
        b= 'marketCap : ' + str(two)
        c= 'bookValue : ' + str(three)
        d= 'sharesOutstanding : ' + str(four)
        e= 'dayLow : ' + str(five)
        f= 'dayHigh : ' + str(six)
        g= 'profitMargins : ' + str(seven)
        h= 'twoHundredDayAverage : ' + str(eight)
        i= 'fiftyTwoWeekHigh : ' + str(nine)
        print(a,a2,b,c,d,e,f,g,h,i)
    
        

    else:
        query = b1
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','finances','of']
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
        a = df[df.companyFinal==result].iloc[0]['Symbol']
        def listToString(s):  
    
     
            str1 = ""  
    
    
            for ele in s:  
                str1 += ele   
    
    
            return str1  
        
        
        
        s = a 
        f= si.get_live_price(listToString(s))
        a1=str(round(f,2))
        tickerdata = yf.Ticker(a)
        tickerinfo = tickerdata.info
        one = tickerinfo['shortName']
        two = tickerinfo['marketCap']
        three = tickerinfo['bookValue']
        four = tickerinfo['sharesOutstanding']
        five = tickerinfo['dayLow']
        six = tickerinfo['dayHigh']
        seven = tickerinfo['profitMargins']
        eight = tickerinfo['twoHundredDayAverage']
        nine = tickerinfo['fiftyTwoWeekHigh']
        
        a= 'shortName : ' + str(one)
        a2 = 'Current Price : ' + a1
        b= 'marketCap : ' + str(two)
        c= 'bookValue : ' + str(three)
        d= 'sharesOutstanding : ' + str(four)
        e= 'dayLow : ' + str(five)
        f= 'dayHigh : ' + str(six)
        g= 'profitMargins : ' + str(seven)
        h= 'twoHundredDayAverage : ' + str(eight)
        i= 'fiftyTwoWeekHigh : ' + str(nine)
        print(a,a2,b,c,d,e,f,g,h,i)

elif(b.find('financials') != -1):
    if (b.find('of') != -1):
        
        mystring = b1
        keyword = 'of ' 
        before_keyword, keyword, after_keyword = mystring.partition(keyword)
        df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
        a = df[df.companyFinal==after_keyword].iloc[0]['Symbol']
        def listToString(s):  
    
     
            str1 = ""  
    
    
            for ele in s:  
                str1 += ele   
    
    
            return str1  
        
        
        
        s = a 
        f= si.get_live_price(listToString(s))
        a1=str(round(f,2))
        
        tickerdata = yf.Ticker(a)
        tickerinfo = tickerdata.info
        one = tickerinfo['shortName']
        two = tickerinfo['marketCap']
        three = tickerinfo['bookValue']
        four = tickerinfo['sharesOutstanding']
        five = tickerinfo['dayLow']
        six = tickerinfo['dayHigh']
        seven = tickerinfo['profitMargins']
        eight = tickerinfo['twoHundredDayAverage']
        nine = tickerinfo['fiftyTwoWeekHigh']
        
        a= 'shortName : ' + str(one)
        a2 = 'Current Price : ' + a1
        b= 'marketCap : ' + str(two)
        c= 'bookValue : ' + str(three)
        d= 'sharesOutstanding : ' + str(four)
        e= 'dayLow : ' + str(five)
        f= 'dayHigh : ' + str(six)
        g= 'profitMargins : ' + str(seven)
        h= 'twoHundredDayAverage : ' + str(eight)
        i= 'fiftyTwoWeekHigh : ' + str(nine)
        print(a,a2,b,c,d,e,f,g,h,i)
    
        

    else:
        query = b1
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','finances','of']
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
        a = df[df.companyFinal==result].iloc[0]['Symbol']
        def listToString(s):  
    
     
            str1 = ""  
    
    
            for ele in s:  
                str1 += ele   
    
    
            return str1  
        
        
        
        s = a 
        f= si.get_live_price(listToString(s))
        a1=str(round(f,2))
        tickerdata = yf.Ticker(a)
        tickerinfo = tickerdata.info
        one = tickerinfo['shortName']
        two = tickerinfo['marketCap']
        three = tickerinfo['bookValue']
        four = tickerinfo['sharesOutstanding']
        five = tickerinfo['dayLow']
        six = tickerinfo['dayHigh']
        seven = tickerinfo['profitMargins']
        eight = tickerinfo['twoHundredDayAverage']
        nine = tickerinfo['fiftyTwoWeekHigh']
        
        a= 'shortName : ' + str(one)
        a2 = 'Current Price : ' + a1
        b= 'marketCap : ' + str(two)
        c= 'bookValue : ' + str(three)
        d= 'sharesOutstanding : ' + str(four)
        e= 'dayLow : ' + str(five)
        f= 'dayHigh : ' + str(six)
        g= 'profitMargins : ' + str(seven)
        h= 'twoHundredDayAverage : ' + str(eight)
        i= 'fiftyTwoWeekHigh : ' + str(nine)
        print(a,a2,b,c,d,e,f,g,h,i)

elif(b.find('financial') != -1):
    if (b.find('of') != -1):
        
        mystring = b1
        keyword = 'of ' 
        before_keyword, keyword, after_keyword = mystring.partition(keyword)
        df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
        a = df[df.companyFinal==after_keyword].iloc[0]['Symbol']
        def listToString(s):  
    
     
            str1 = ""  
    
    
            for ele in s:  
                str1 += ele   
    
    
            return str1  
        
        
        
        s = a 
        f= si.get_live_price(listToString(s))
        a1=str(round(f,2))
        
        tickerdata = yf.Ticker(a)
        tickerinfo = tickerdata.info
        one = tickerinfo['shortName']
        two = tickerinfo['marketCap']
        three = tickerinfo['bookValue']
        four = tickerinfo['sharesOutstanding']
        five = tickerinfo['dayLow']
        six = tickerinfo['dayHigh']
        seven = tickerinfo['profitMargins']
        eight = tickerinfo['twoHundredDayAverage']
        nine = tickerinfo['fiftyTwoWeekHigh']
        
        a= 'shortName : ' + str(one)
        a2 = 'Current Price : ' + a1
        b= 'marketCap : ' + str(two)
        c= 'bookValue : ' + str(three)
        d= 'sharesOutstanding : ' + str(four)
        e= 'dayLow : ' + str(five)
        f= 'dayHigh : ' + str(six)
        g= 'profitMargins : ' + str(seven)
        h= 'twoHundredDayAverage : ' + str(eight)
        i= 'fiftyTwoWeekHigh : ' + str(nine)
        print(a,a2,b,c,d,e,f,g,h,i)
    
        

    else:
        query = b1
        stopwords = ['news', 'who', 'is', 'a', 'at', 'is', 'he','meaning','finances','of']
        querywords = query.split()
        resultwords  = [word for word in querywords if word.lower() not in stopwords]
        result = ' '.join(resultwords)
        df = pd.read_csv("tickers2.csv", encoding = "ISO-8859-1") 
        a = df[df.companyFinal==result].iloc[0]['Symbol']
        def listToString(s):  
    
     
            str1 = ""  
    
    
            for ele in s:  
                str1 += ele   
    
    
            return str1  
        
        
        
        s = a 
        f= si.get_live_price(listToString(s))
        a1=str(round(f,2))
        tickerdata = yf.Ticker(a)
        tickerinfo = tickerdata.info
        one = tickerinfo['shortName']
        two = tickerinfo['marketCap']
        three = tickerinfo['bookValue']
        four = tickerinfo['sharesOutstanding']
        five = tickerinfo['dayLow']
        six = tickerinfo['dayHigh']
        seven = tickerinfo['profitMargins']
        eight = tickerinfo['twoHundredDayAverage']
        nine = tickerinfo['fiftyTwoWeekHigh']
        
        a= 'shortName : ' + str(one)
        a2 = 'Current Price : ' + a1
        b= 'marketCap : ' + str(two)
        c= 'bookValue : ' + str(three)
        d= 'sharesOutstanding : ' + str(four)
        e= 'dayLow : ' + str(five)
        f= 'dayHigh : ' + str(six)
        g= 'profitMargins : ' + str(seven)
        h= 'twoHundredDayAverage : ' + str(eight)
        i= 'fiftyTwoWeekHigh : ' + str(nine)
        print(a,a2,b,c,d,e,f,g,h,i)

        
else:
    df = pd.read_csv("csv_test.csv")
    a1 = df[df.type1==b].to_numpy()
    print(a1)
# Out:
# speakNow
# latest news on apple
# How to Watch Apple TV's New MTV-Style Music Channel
# How to Watch Today's Apple iPhone 12 Event
# Apple Music TV is a 24-hour stream of music videos, shows and events
# Apple Watch's 'Schooltime' Isn't Just for Kids
# Apple sues recycling partner for reselling more than 100,000 iPhones, iPads and Watches it was hired to dismantle
# Apple outage is causing iCloud, App Store, Music and TV+ problems
# Apple pulls TV Remote app now that it's built into iOS
# Bloomberg: Apple Stores drop most third-party headphones and speakers
# You Can Now Change All Your Ring Goals in watchOS 7
# Judge won't let Apple block Unreal Engine, but won't make it unblock 'Fortnite'
# Apple One subscription bundle launches on October 30th
# Google Play Movies & TV is now Google TV but it’s not the same Google TV that runs on Android TV on the new Chromecast, it’s an app
# Automatically Change Your Apple Watch Face by Location or Time
# ...
